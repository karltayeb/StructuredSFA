# %% [markdown]
# We will train a bunch of ssfas while dropping samples. The idea is to see if we can recover similar factors with less data

# %%
from sfa import SparseFactorAnalyzer
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
data_path = 'data/variance_stabilized.csv'
pheno_path = 'data/phenotype.csv'
data = pd.read_csv(data_path, index_col=0)
phenotype = pd.read_csv(pheno_path, index_col=0)

# %%
plt.hist(phenotype.DAY, bins=20)
plt.show()

# %%
np.random.seed(121)
phenotype20 = phenotype.groupby('DAY').apply(lambda x: x.sample(frac=0.2))
phenotype40 = phenotype.groupby('DAY').apply(lambda x: x.sample(frac=0.4))
phenotype60 = phenotype.groupby('DAY').apply(lambda x: x.sample(frac=0.6))
phenotype80 = phenotype.groupby('DAY').apply(lambda x: x.sample(frac=0.8))
phenotype100 = phenotype

# %%
small_data = data.loc[data.var(axis=1).nlargest(10000).index]
small_data = data.loc[small_data.var(axis=1).nsmallest(9500).index]

val_index = np.random.choice(9500, 1000, replace=False)
cross_val_data = small_data.iloc[val_index]

train_index = np.random.choice(8500, 3000, replace=False)
train_data = small_data.drop(cross_val_data.index)
train_data = train_data.iloc[train_index]

# %%
np.random.seed(131)

sfa20 = SparseFactorAnalyzer(k_components=30, data=train_data.loc[:, phenotype20.SampleID.values])

sfa40 = SparseFactorAnalyzer(k_components=30, data=train_data.loc[:, phenotype40.SampleID.values])

sfa60 = SparseFactorAnalyzer(k_components=30, data=train_data.loc[:, phenotype60.SampleID.values])

sfa80 = SparseFactorAnalyzer(k_components=30, data=train_data.loc[:, phenotype80.SampleID.values])

sfa100 = SparseFactorAnalyzer(k_components=30, data=train_data.loc[:, phenotype100.SampleID.values])

# %%
pickle.dump(sfa20, open('output/sfa20', 'wb'))
pickle.dump(sfa40, open('output/sfa40', 'wb'))
pickle.dump(sfa60, open('output/sfa60', 'wb'))
pickle.dump(sfa80, open('output/sfa80', 'wb'))
pickle.dump(sfa100, open('output/sfa100', 'wb'))

for i in range(25):
    try:
        sfa20.ecme(iters=5, structured=True, scale=True, verbose=True)
        pickle.dump(sfa20, open('output/sfa20', 'wb'))
    except:
        pass
    
    try:
        sfa40.ecme(iters=5, structured=True, scale=True, verbose=True)
        pickle.dump(sfa40, open('output/sfa40', 'wb'))
    except:
        pass
    
    try:
        sfa60.ecme(iters=5, structured=True, scale=True, verbose=True)
        pickle.dump(sfa60, open('output/sfa60', 'wb'))
    except:
        pass
    
    try:
        sfa80.ecme(iters=5, structured=True, scale=True, verbose=True)
        pickle.dump(sfa80, open('output/sfa80', 'wb'))
    except:
        pass
    
    try:
        sfa100.ecme(iters=5, structured=True, scale=True, verbose=True)
        pickle.dump(sfa100, open('output/sfa100', 'wb'))
    except:
        pass
# Out:
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', inf)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', inf)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', inf)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', inf)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', inf)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 471005.03365528845)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 459764.76676089119)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 471936.08831430867)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 349149.32743569236)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 507293.44414370967)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 4095.6255704171599)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 5974.6696740662155)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 6683.0014211240632)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 9772.8386108592094)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 10671.545403823751)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 779.25498139149931)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1611.1852669420041)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1796.4549981492455)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 3170.5108536647167)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 4381.2663762754819)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 382.62392252252539)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 764.17029017482128)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1022.4741998493555)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1585.8021114906296)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 2664.469798277074)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 256.19405152715626)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 428.88759715063497)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 641.87253618624527)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 994.6107420118351)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1889.8532764714619)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 185.57510080010252)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 302.25401461950969)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 412.67996175901499)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 749.19276523470762)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1375.732246386382)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 90.187460210399877)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 182.48420195026847)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 253.19819432561053)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 497.76613612656365)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 1018.0947711640038)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 82.490870363188151)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 123.42950408621982)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 212.98841400726815)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 408.57172656041803)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 764.53878761717351)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 72.07809651669595)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 121.22187651565764)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 197.47445743586286)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 363.16232805539039)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 556.31002441723831)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 96.712244115969952)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 149.12952163846057)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 170.93707177515898)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 331.28600053099217)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 464.08247395226499)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 67.710904398103594)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 149.78320881861146)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 164.89552118496795)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 334.87092387591838)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 391.31785666139331)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 44.474054081423674)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 105.52914610503649)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 115.32484759707586)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 386.06157873888151)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 349.9496636526892)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 33.619449559111672)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 94.789861587501946)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 100.19018918546499)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 316.14564243264613)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 259.40784938426805)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 32.18592053773682)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 91.666516458368278)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 102.39240261557279)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 284.88340279960539)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 263.1965320178715)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 27.286344396208733)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 112.24072048989183)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 134.52375001186738)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 251.30746016174089)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 266.5914669019694)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 24.482199207981466)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 121.79936881807225)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 131.19351586684934)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 235.66651492140954)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 277.54059001113637)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 31.54204359191499)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 135.99629288326832)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 56.642851870390587)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 235.90160899731563)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 236.69702219517785)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 34.112275258645241)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 149.30435214148019)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 82.890476429602131)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 189.68549001612701)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 198.04402914107777)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 42.63260354623344)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 137.59312907654385)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 87.915241453287308)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 169.5727820469474)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 220.08666135536623)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 56.053196594206383)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 122.29095162422163)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 70.250403157042456)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 151.03278913619579)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 175.14664516059565)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 45.318665925158712)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 107.33305363554973)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 65.76819867285667)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 186.26598858728539)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 146.25975918941549)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 29.440247959013504)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 109.1429108033044)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 81.619091710206703)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 140.26912464789348)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 111.16930493208929)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 25.393762806161249)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 82.642410866639693)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 86.692114773803041)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 130.81263198141824)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 62.327245705761015)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 36.090504095409415)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 100.70814198182779)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 31.486941306182416)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 131.9616642757901)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# (0, 'expected log likelihood has improved by:', 37.810039486415917)
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
# updating lambda
# updating psi
# updating sigma2
# updating F
# scaling F, sigma2
